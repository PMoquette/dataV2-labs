# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import json
import requests
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
username = 'PMoquette'
token = '7ac38bebc20cd90020a312950d300f1b4565b1f4'

response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/forks', auth=(username,token))
data = response.json()

# %%
flattened_data = json_normalize(data)
flattened_data.head(10)
# Out:
#           id                           node_id         name  \
# 0  244963291  MDEwOlJlcG9zaXRvcnkyNDQ5NjMyOTE=  dataV2-labs
# 1  242350251  MDEwOlJlcG9zaXRvcnkyNDIzNTAyNTE=  dataV2-labs
# 2  241335460  MDEwOlJlcG9zaXRvcnkyNDEzMzU0NjA=  dataV2-labs
# 3  241335029  MDEwOlJlcG9zaXRvcnkyNDEzMzUwMjk=  dataV2-labs
# 4  241334117  MDEwOlJlcG9zaXRvcnkyNDEzMzQxMTc=  dataV2-labs
# 5  241333755  MDEwOlJlcG9zaXRvcnkyNDEzMzM3NTU=  dataV2-labs
# 6  241332555  MDEwOlJlcG9zaXRvcnkyNDEzMzI1NTU=  dataV2-labs
# 7  241331710  MDEwOlJlcG9zaXRvcnkyNDEzMzE3MTA=  dataV2-labs
# 8  241331561  MDEwOlJlcG9zaXRvcnkyNDEzMzE1NjE=  dataV2-labs
# 9  241331355  MDEwOlJlcG9zaXRvcnkyNDEzMzEzNTU=  dataV2-labs
#
#                    full_name  private  \
# 0          camdw/dataV2-labs    False
# 1    ta-data-lis/dataV2-labs    False
# 2      pmoreira1/dataV2-labs    False
# 3        mazzoal/dataV2-labs    False
# 4          c-cle/dataV2-labs    False
# 5      ReneRaube/dataV2-labs    False
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
flattened_data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
language_url = list(flattened_data["languages_url"])
language_url
# Out:
# ['https://api.github.com/repos/camdw/dataV2-labs/languages',
#  'https://api.github.com/repos/ta-data-lis/dataV2-labs/languages',
#  'https://api.github.com/repos/pmoreira1/dataV2-labs/languages',
#  'https://api.github.com/repos/mazzoal/dataV2-labs/languages',
#  'https://api.github.com/repos/c-cle/dataV2-labs/languages',
#  'https://api.github.com/repos/ReneRaube/dataV2-labs/languages',
#  'https://api.github.com/repos/PatrickColijn/dataV2-labs/languages',
#  'https://api.github.com/repos/Katja-Galyuk/dataV2-labs/languages',
#  'https://api.github.com/repos/PMoquette/dataV2-labs/languages',
#  'https://api.github.com/repos/diogoacabado/dataV2-labs/languages',
#  'https://api.github.com/repos/MafaldaFragoso/dataV2-labs/languages',
#  'https://api.github.com/repos/llopisaleix/dataV2-labs/languages',
#  'https://api.github.com/repos/AlvaroGSP/dataV2-labs/languages',
#  'https://api.github.com/repos/raphaeleon13/dataV2-labs/languages',
# ...

# %%
# your code here

language_response = []

for url in language_url:
    x = requests.get(url, auth=(username,token)).json()
    language_response.append(x)

# %%
list(language_response)
# Out:
# [{'Jupyter Notebook': 2464680, 'HTML': 498316, 'Python': 9907},
#  {'Jupyter Notebook': 2464663, 'HTML': 498316, 'Python': 9907},
#  {'Jupyter Notebook': 3813214, 'HTML': 498316, 'TSQL': 6759, 'Python': 4720},
#  {'Jupyter Notebook': 3537132,
#   'HTML': 498316,
#   'Rich Text Format': 13142,
#   'Python': 9907},
#  {'Jupyter Notebook': 5579483, 'HTML': 498316, 'Python': 9907, 'TSQL': 3453},
#  {'Jupyter Notebook': 3823589,
#   'HTML': 498316,
#   'Python': 9907,
#   'Rich Text Format': 3552},
#  {'Jupyter Notebook': 4974539, 'HTML': 498316, 'Python': 12839},
#  {'Jupyter Notebook': 3483956, 'HTML': 498316, 'Python': 9907},
#  {'Jupyter Notebook': 6465569, 'HTML': 498316, 'Python': 11169, 'TSQL': 1578},
#  {'Jupyter Notebook': 5451560, 'HTML': 498316, 'TSQL': 122435, 'Python': 9907},
#  {'Jupyter Notebook': 4378013, 'HTML': 498316, 'Python': 9907, 'TSQL': 294},
#  {'Jupyter Notebook': 2464662, 'HTML': 498316, 'Python': 9907},
# ...

# %%
language_unique = []

for item in language_response:
    for language in item:
        language_unique.append(language)

np.unique(language_unique)
# Out:
# array(['HTML', 'Jupyter Notebook', 'Python', 'Rich Text Format', 'TSQL'],
#       dtype='<U16')

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
#response = requests.get('https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?since=2019-10-01T00:00:00Z&until2019-10-31T23:59:59Z', auth=(username,token))
#commits = response.json()
#flattened_commits = json_normalize(commits)
#flattened_commits.head(10)
#https://stackoverflow.com/questions/53773904/python-to-retrieve-multiple-pages-of-data-from-api-with-get

for page in range(1,20):
    url = 'https://api.github.com/repos/ironhack-datalabs/dataV2-labs/commits?since=2019-10-01T00:00:00Z&until2019-10-31T23:59:59Z?page={}'.format(page)
    response = requests.get(url,auth=(username,token))
    commit_response = response.json()

flattened_commits = json_normalize(commit_response)
flattened_commits.head(60)
# Out:
#                                          sha  \
# 0   680a9ca1cebd77383a8a104ab48c868d1600790f
# 1   1421d2b97b1e250bbd1c321e7c38a1ef87fd2c49
# 2   023a27f4c4bb515a77bfda08f9309c1b1e333e72
# 3   574666b2fc86a71f60f334545fe4d16ab61ab28f
# 4   6f83d1446dbb6bd600a2082e8147b79e420f581b
# 5   37e0b0681ff829d1c9f4a542631229efe7d577ff
# 6   d9da31ef64900ad297d5d811d4f9c45e66fa8e8f
# 7   957cd5b2250076833fce0f363b42b4a77660e4eb
# 8   48503eb5aff61da2e7c1fdd55f3f7e407360ad29
# 9   a0cc914495a7e137e298cd6f5d47948b5cf64807
# 10  736bb6168cf59f0bfdc571e69db7986f7e5d54cb
# 11  b486d8528d53b940fb463850d6f841fa246607ef
# 12  974a906cc69c937b98f14a6c41f21a8fcb052082
# 13  e72aefda9202d5c9d06e3781d12dc8d79391857e
# 14  a3973031929ef5b1d8e30a2ff65c871423dae961
# 15  1184709677c2ffa1a674529c2c77fcdd3ebc647a
# 16  166c02fbaf7dd2908454f06e5cbbcddbcfb46361
# 17  eb96641d7cfafd678f4a306e7dff98d7448c11a5
# 18  44714932eed6b619ba67eb38448c5e9181334507
# 19  0bbbbc921961e66b5318d30a58482b8b79dc2612
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
#flattened_commits.columns

len(flattened_commits)
# Out:
# 30

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents', auth=(username,token))
hunt = response.json()

hunt
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
type(hunt)
# Out:
# list

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
#What I need: contents_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{+path}'

'''files = []

for file in hunt:
    file_name = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}'.format(url for url in file if url == 'url'), auth=(username,token)).json()
    files.append(file_name) 
files

len(files)
'''

url_list = [d['url'] for d in hunt]
url_list = [url for url in url_list if 'gitignore' not in url]
url_list

files = []

for url in url_list:
    contents = requests.get(url, auth=(username,token)).json()
    files.append(contents)   
files
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
scavenger_files = [val['name'] for sublist in files for val in sublist]
scavenger_files

hunt_files = [file for file in scavenger_files if 'scavengerhunt' in file]
hunt_files.sort()
hunt_files
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
#I now know the filenames, need to find corresponding paths.
scavenger_url = [val['url'] for sublist in files for val in sublist]
scavenger_url

scavenger_url = [file for file in scavenger_url if 'scavengerhunt' in file]
scavenger_url.sort()
scavenger_url

sorted_url = sorted(scavenger_url, key = lambda x: x.split(".")[3])
sorted_url
# Out:
# ['https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/88596/.0002.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/60224/.0003.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/68848/.0004.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/44639/.0005.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/17020/.0007.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15534/.0008.scavengerhunt?ref=master',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/97881/.0009.scavengerhunt?ref=master',
# ...

# %%
# your code here

headers = {'Accept': 'application/vnd.github.v3.raw'}

joke_response = []

for url in sorted_url:
    x = requests.get(url, headers=headers, auth=(username,token)).text
    joke_response.append(x) 

joke_response
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

joke = [i.strip() for i in joke_response]
joke = ' '.join(joke)

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
