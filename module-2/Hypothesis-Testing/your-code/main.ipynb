# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents. Please, load the data using Ironhack's database (db: employees, table: employees_advanced).

# %%
# Your code here:
data = pd.read_csv('../Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:
data.head()
# Out:
#                      Name                 Job Titles        Department  \
# 0  ADRIANO,  RACQUEL ANNE                  PARAMEDIC              FIRE
# 1       AFFANEH,  MAHIR A             POLICE OFFICER            POLICE
# 2       AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 3         AGAR,  BULENT B        DEPUTY COMMISSIONER       WATER MGMNT
# 4         AGEE,  LAWRENCE             POLICE OFFICER            POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN        72510.0
# 1                 F           Salary            NaN        93354.0
# 2                 P           Hourly           20.0            NaN
# 3                 F           Salary            NaN       132972.0
# 4                 F           Salary            NaN        90024.0
#
#    Hourly Rate
# 0          NaN
# 1          NaN
# 2         13.0
# 3          NaN
# 4          NaN

# %%
data.shape
# Out:
# (33702, 8)

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
null_cols = data.isnull().sum()
null_cols
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25528
# Annual Salary         8174
# Hourly Rate          25528
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
data['Salary or Hourly'].value_counts()
# Out:
# Salary    25528
# Hourly     8174
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
data['Department'].value_counts()
# Out:
# POLICE                 13848
# FIRE                    4627
# STREETS & SAN           2175
# WATER MGMNT             1914
# AVIATION                1856
# OEMC                    1737
# TRANSPORTN              1113
# PUBLIC LIBRARY          1088
# DAIS                    1033
# FAMILY & SUPPORT         656
# FINANCE                  544
# HEALTH                   467
# LAW                      398
# CITY COUNCIL             362
# BUILDINGS                258
# PUBLIC SAFETY ADMIN      244
# BUSINESS AFFAIRS         167
# HOUSING & ECON DEV       154
# COPA                     123
# BOARD OF ELECTION        111
# MAYOR'S OFFICE           104
# INSPECTOR GEN             95
# CITY CLERK                88
# PROCUREMENT               84
# HUMAN RESOURCES           75
# ANIMAL CONTRL             75
# CULTURAL AFFAIRS          74
# HOUSING                   66
# BUDGET & MGMT             44
# ADMIN HEARNG              38
# DISABILITIES              28
# TREASURER                 28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:
from scipy.stats import ttest_1samp
hourly_wage = data['Hourly Rate'].dropna()
print(np.mean(hourly_wage))
ttest_1samp(hourly_wage, 30)
# Out:
# 34.58644971862046
# Ttest_1sampResult(statistic=31.211500329216044, pvalue=3.825475847673794e-202)

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
police_data = data[data['Department'] == 'POLICE']['Annual Salary'].dropna()
police_data.head()                                    
np.mean(police_data)
#So H0 = salaries this year are the same or lower than last year's mean of 86000.
#H1 = salaries this year are higher than last year's mean of 86000
stats, pvalue = ttest_1samp(police_data, 86000)
print(stats, pvalue)

pvalue_onesided = pvalue/2
print(pvalue_onesided)
# Out:
# 18.51748561981861 1.2239133904242963e-75
# 6.119566952121482e-76

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:

pd.crosstab(data['Department'], data['Salary or Hourly'], dropna=False)
# Out:
# Salary or Hourly     Hourly  Salary
# Department
# ADMIN HEARNG              0      38
# ANIMAL CONTRL            12      63
# AVIATION               1214     642
# BOARD OF ELECTION         0     111
# BOARD OF ETHICS           0       8
# BUDGET & MGMT             2      42
# BUILDINGS                 0     258
# BUSINESS AFFAIRS          7     160
# CITY CLERK                0      88
# CITY COUNCIL             74     288
# COPA                      0     123
# CULTURAL AFFAIRS         10      64
# DAIS                    745     288
# DISABILITIES              1      27
# FAMILY & SUPPORT        357     299
# FINANCE                  45     499
# FIRE                      0    4627
# HEALTH                    2     465
# HOUSING                   0      66
# HOUSING & ECON DEV        3     151
# HUMAN RELATIONS           0      17
# HUMAN RESOURCES           0      75
# INSPECTOR GEN             0      95
# LAW                      48     350
# ...

# %%
pd.crosstab(data.Department, data['Salary or Hourly']).sort_values(by='Hourly', ascending=False )
# Out:
# Salary or Hourly     Hourly  Salary
# Department
# STREETS & SAN          1846     329
# WATER MGMNT            1558     356
# AVIATION               1214     642
# OEMC                   1077     660
# DAIS                    745     288
# TRANSPORTN              726     387
# FAMILY & SUPPORT        357     299
# PUBLIC LIBRARY          356     732
# CITY COUNCIL             74     288
# LAW                      48     350
# PUBLIC SAFETY ADMIN      48     196
# FINANCE                  45     499
# POLICE                   24   13824
# MAYOR'S OFFICE           17      87
# ANIMAL CONTRL            12      63
# CULTURAL AFFAIRS         10      64
# BUSINESS AFFAIRS          7     160
# HOUSING & ECON DEV        3     151
# PROCUREMENT               2      82
# HEALTH                    2     465
# BUDGET & MGMT             2      42
# DISABILITIES              1      27
# POLICE BOARD              0       2
# TREASURER                 0      28
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
# Department with most hourly workers is STREETS & SAN. 
streets_san_data = data[data['Department'] == 'STREETS & SAN']['Hourly Rate'].dropna()
streets_san_data

#H0: hourly wage is equal to or higher than $35/hour
#H1: hourly wage is less than $35/hour

stats1, pvalue1 = ttest_1samp(streets_san_data, 35)
print(stats1, pvalue1)

pvalue_onesided1 = pvalue1/2
print(pvalue_onesided1)
# Out:
# 4.000138803968834 6.580474443773579e-05
# 3.2902372218867895e-05

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:
# construct a 95% confidence interval for the mean hourly wage of all hourly workers
#0.95 confidence level, degrees of freedom = (df.shape[0] as n rows) - 1, mean of sample=loc, standard error=scale.
# mean hourly wage was calculated earier:
#print(hourly_wage)


hourly_wage
#print(np.mean(hourly))
#print(hourly.shape[0])


#stats.sem(hourly['Hourly Rate'])
#hourly.head()
#hourly.isna().sum()
#I keep getting the error: 'numpy.float64' object has no attribute 'sem'
#I have tried converting the hourly rate from float64 to normal float in several different ways, 
#I have tried converting hourly_wage (from earlier challenge) back to a pd dataframe,
#I keep getting this error. I don't know why.
# Out:
# 2        13.00
# 5        37.45
# 15       40.78
# 16       38.52
# 21       34.98
#          ...
# 33676    25.95
# 33678    43.72
# 33681    51.43
# 33684    49.35
# 33688    37.45
# Name: Hourly Rate, Length: 8174, dtype: float64

# %%
# Tried starting from scratch with new dataset:
hourly = data[data['Salary or Hourly'] == 'Hourly']
hourly
# Out:
#                          Name                      Job Titles  \
# 2           AFOENYI,  PHYLLIS       TITLE V PROGRAM TRAINEE I
# 5           AGNEW,  ANTONIO E              MOTOR TRUCK DRIVER
# 15         AGSALUD,  FERNAN S              SANITATION LABORER
# 16     AGSALUD JR,  JUANITO S              SANITATION LABORER
# 21            AGUAYO,  LUIS M            LABORER - APPRENTICE
# ...                       ...                             ...
# 33676         ZUNIGA,  THOMAS           GENERAL LABORER - DSS
# 33678             ZUNO,  ERIK            CONSTRUCTION LABORER
# 33681      ZURAWSKI,  JEFFREY  FRM OF MACHINISTS - AUTOMOTIVE
# 33684         ZUREK,  FRANCIS             ELECTRICAL MECHANIC
# 33688      ZWARYCZ,  THOMAS J              MOTOR TRUCK DRIVER
#
#                 Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 2         FAMILY & SUPPORT                 P           Hourly           20.0
# ...

# %%
# construct a 95% confidence interval for the mean hourly wage of all hourly workers
#0.95 confidence level, degrees of freedom = (df.shape[0] as n rows) - 1, mean of sample=loc, standard error=scale.
# mean hourly wage was calculated earier:
#print(hourly_wage)
degrees_freedom = n - 1
standard_error = hourly_wage.sem()
mu = np.mean(hourly_wage)
n = hourly.shape[0]
print(degrees_freedom)
print(standard_error)
print(mu)
print(n)
# Out:
# 8173
# 0.14694742867989846
# 34.58644971862046
# 8174

# %%
#Same error again, so I will do it manually. This is ridiculous. 
conf_interval = stats.t.interval(0.95, 8173, loc=34.58644971862046, scale=0.14694742867989846)
#Also doesn't work.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-50bdc2c56b51> in <module>
#       1 #Same error again, so I will do it manually. This is ridiculous.
# ----> 2 conf_interval = stats.t.interval(0.95, 8173, loc=34.58644971862046, scale=0.14694742867989846)
#
# AttributeError: 'numpy.float64' object has no attribute 't'

# %%
#This code was copied from Pedro. His works. Mine returns the numpy.float64 object has no attribute "sem" error. 
#I'm going to open a new Jupyter notebook and try this specific exercise alone. See "error-test" in same folder.
hourly_salaries = data[data['Salary or Hourly'] == 'Hourly']
hourly_salaries_mean = np.mean(hourly_salaries['Hourly Rate'])

degrees_freedom = len(hourly_salaries)-1
l = np.mean(hourly_salaries['Hourly Rate'])
s = stats.sem(hourly_salaries['Hourly Rate'])
conf_level = 0.95
conf_interval = stats.t.interval(conf_level, df=degrees_freedom, loc=l, scale=s)
print(conf_interval)
print("The 95% interval is between", round(conf_interval[0],2), "and",round(conf_interval[1],2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ad0c49ac799b> in <module>
#       4 degrees_freedom = len(hourly_salaries)-1
#       5 l = np.mean(hourly_salaries['Hourly Rate'])
# ----> 6 s = stats.sem(hourly_salaries['Hourly Rate'])
#       7 conf_level = 0.95
#       8 conf_interval = stats.t.interval(conf_level, df=degrees_freedom, loc=l, scale=s)
#
# AttributeError: 'numpy.float64' object has no attribute 'sem'

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Your code here:
#Also in error-test

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
