# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, linewidth= 2, color='b', label='linear')
plt.plot(x, z, linewidth= 2, color='y', label='quadratic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("First Way")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
'''
Examples: https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.subplot.html
https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html
https://matplotlib.org/3.2.0/api/_as_gen/matplotlib.pyplot.subplot.html

plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title



# equivalent but more general

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

'''
plt.figure()
plt.subplot(121)
plt.plot(x,y)

plt.subplot(122)
plt.plot(x,z)
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
'''f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.plot(x, y)
ax2.plot(x, z)

fig = plt.figure(figsize=(8, 20))
'''

fig, [ax1, ax2] = plt.subplots(1,2,figsize=(20,10))

ax1.plot(x,y)
ax1.set_xlabel("Linear")
ax2.plot(x,z)
ax2.set_xlabel("Quadratic")
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y = x**2
z = np.exp(x)

# %%
fig, [ax1, ax2] = plt.subplots(1,2,figsize=(10,5))

ax1.plot(x,y)
ax1.set_xlabel("Quadratic")
ax2.plot(x,z)
ax2.set_xlabel("Logarithmic")
ax2.set_xscale("log")
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
import pandas as pd
fitbit = pd.read_csv("../Fitbit2.csv")
print(fitbit.shape)
fitbit.head()
# Out:
# (367, 24)
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
#Helpful link: https://towardsdatascience.com/data-visualization-using-matplotlib-16f1aae5ce70
'''Median steps per month, these are integers (discrete: whole steps). 
Consulting the Chartguide, I'd say we're dealing with Time and could do either a dot-line-chart (aggregated in time),
or a column chart. 
data_frame.resample("1Min", how="sum")
https://stackoverflow.com/questions/29248280/aggregate-time-series-in-python
'''
#Data manipulation for analysis:

avg_steps_month = fitbit.groupby('Months_encoded', as_index=False).agg({'Steps':'mean'})
avg_steps_month.head()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
# M represents median
M_steps_week_end = fitbit.groupby('Work_or_Weekend', as_index=False).agg({'Steps':'median'})
M_steps_week_end.head()
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
avg_steps_month.head(12)
# Out:
#     Months_encoded         Steps
# 0                1   9892.064516
# 1                2   8922.866667
# 2                3  10312.935484
# 3                4  13079.033333
# 4                5  10620.096774
# 5                6  12536.166667
# 6                7   9193.322581
# 7                8  11584.774194
# 8                9   9191.333333
# 9               10   8272.451613
# 10              11   9467.466667
# 11              12   8470.064516

# %%
fig, [ax1, ax2] = plt.subplots(1,2,figsize=(12,4))

ax1.plot(avg_steps_month['Months_encoded'], avg_steps_month['Steps'], color='blue')
ax1.set_title('Average steps per month')   
ax1.set_xlabel('Months')     
ax1.set_ylabel('Steps') 

bars = ('Weekend', 'Work')
y_pos = [0,1]
ax2 = plt.bar(M_steps_week_end['Work_or_Weekend'], M_steps_week_end['Steps'])
plt.xticks(y_pos, bars)
# Out:
# ([<matplotlib.axis.XTick at 0x11c954910>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
list_columns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

plt.figure(figsize=(20,10))
for x in list_columns:
    x = fitbit[x]
    y = fitbit["Steps"]
    plt.scatter(x,y,label=x)
    plt.xlabel('Minutes')
    plt.ylabel('Steps')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(exclude ='object')
# Out:
#      Survived  Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0           0       3  22.0                        1                        0
# 1           1       1  38.0                        1                        0
# 2           1       3  26.0                        0                        0
# 3           1       1  35.0                        1                        0
# 4           0       3  35.0                        0                        0
# ..        ...     ...   ...                      ...                      ...
# 882         0       2  27.0                        0                        0
# 883         1       1  19.0                        0                        0
# 884         0       3   7.0                        1                        2
# 885         1       1  26.0                        0                        0
# 886         0       3  32.0                        0                        0
#
#         Fare
# 0     7.2500
# ...

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include ='object')
# Out:
#                                                   Name     Sex
# 0                               Mr. Owen Harris Braund    male
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  female
# 2                                Miss. Laina Heikkinen  female
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  female
# 4                              Mr. William Henry Allen    male
# ..                                                 ...     ...
# 882                               Rev. Juozas Montvila    male
# 883                        Miss. Margaret Edith Graham  female
# 884                     Miss. Catherine Helen Johnston  female
# 885                               Mr. Karl Howell Behr    male
# 886                                 Mr. Patrick Dooley    male
#
# [887 rows x 2 columns]

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
sns.set(rc={"figure.figsize": (12, 6)})
sns.set_style("whitegrid")

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axes = plt.subplots(1,3)
sns.distplot(titanic['Age'],bins=10,ax=axes[0])
sns.distplot(titanic['Age'],bins=20,ax=axes[1])
sns.distplot(titanic['Age'],bins=50,ax=axes[2])
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Readability (lower) and representation (higher)
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
gender_data = titanic.groupby('Sex')['Name'].agg('count')
gender_data
# Out:
# Sex
# female    314
# male      573
# Name: Name, dtype: int64

# %%
# Method 1 - matplotlib
# your code here
labels = ['Female', 'Male']
sizes = [314,573]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.barplot(x=titanic['Sex'].value_counts().index,y=titanic['Sex'].value_counts().values)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
#sns.distplot(titanic['Pclass'])
sns.distplot(titanic['Pclass'], bins=5, kde=False)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic['Age'].hist(bins=80)

# %%
"""
A histogram is an approximate representation of the distribution of numerical or categorical data. 
In other words, a histogram can tell us what age categories were represented in the data, what the mean lies and what the shape of the data is
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
mean is likely to be somewhere between 18 and 28, it is slightly skewed to the right, which will draw the avg age upward
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Seeing as I chose a distribution plot for both, I'm not sure.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
from sklearn.linear_model import LinearRegression
x = np.array(titanic['Fare']).reshape(-1,1)
y = np.array(titanic['Age']).reshape(-1,1)

linear_regressor = LinearRegression() 
linear_regressor.fit(x, y) 
y_pred = linear_regressor.predict(x)

plt.scatter(x, y)
plt.plot(x, y_pred, color='pink')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.regplot(x=titanic['Fare'], y=titanic['Age'], data=titanic)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
#fixed the weird cutoff issue: https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot
heat_map = sns.heatmap(titanic.corr(), annot = True)
bottom, top = heat_map.get_ylim()
heat_map.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (6.0, 0.0)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Most correlated are Siblings/Spouses Aboard and Parents/Children Aboard.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
plt.scatter(titanic['Pclass'], titanic['Age'])

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.set(style="ticks")
titanic = sns.load_dataset("titanic")
sns.relplot(x='sex', y='age', hue="sex", data=titanic)
#??
